# %%
# parte que chamamos de celula, onde podemos digitar o codigo. Exemplo:
x = 10
y = 5
print(x+y)
# não necessariamente precisa do print
x+y
# Out:
# 15
# 15

# %%
## Pandas documentation
# https://pandas.pydata.org/docs/

# df = dataframe
# columns = colunas
# rows = linhas

import pandas as pd

dados = pd.read_csv("dataSet's/fifa.csv")

dados
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
# outros arquivos que podem ser lidos via pandas

# dados_xlsx = pd.read_excel("dataSet's/fifa.xlsx")

# dados_txt = pd.read_csv("dataSet's/fifa.txt", delimiter = '\t')

dados_html = pd.read_html("https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:P%C3%A1gina_principal")

dados_html
# Out:
# [                                                   0  \
#  0  Boas-vindas à Wikipédia, a enciclopédia livre ...
#
#                                                     1
#  0  1 122 277 artigos em português 8 381 editores ...  ,
#        0           1        2          3          4         5           6  \
#  0  Arte  Biografias  Ciência  Filosofia  Geografia  História  Matemática
#
#             7           8
#  0  Sociedade  Tecnologia  ,
#                                                     0  \
#  0                                  Sobre a Wikipédia
#  1  A Wikipédia é um projeto de enciclopédia colab...
#
#                                                     1                  2
#  0                                  Sobre a Wikipédia  Sobre a Wikipédia
#  1  Importante! Princípio da imparcialidade Versõe...                NaN  ,
#                                                     0                1  \
#  0                                    Projetos-irmãos  Projetos-irmãos
# ...

# %%
import pandas as pd

dados = pd.read_csv("dataSet's/fifa.csv")

dados
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
# mostra os 5 primeiros
dados.head()
# posso colocar um numero, onde no head vai correr de forma crescente
#dados.head(7)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# mostra os 5 ultimos
dados.tail()
# posso colocar um numero, onde no tail vai correr de forma decrescente
#dados.tail(10)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %%
#verificar quais são as colunas
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
#verificar a quantidade de linhas
dados.index
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %%
#mostrar somente uma coluna
dados['Name']
#puxar mais de uma coluna insiro a virgula e insere mais um [ ]
dados[['Name', 'Nationality', 'Wage']]
# Out:
#                      Name Nationality   Wage
# 0                L. Messi   Argentina  €565K
# 1       Cristiano Ronaldo    Portugal  €405K
# 2               Neymar Jr      Brazil  €290K
# 3                  De Gea       Spain  €260K
# 4            K. De Bruyne     Belgium  €355K
# ...                   ...         ...    ...
# 18202        J. Lundstram     England    €1K
# 18203  N. Christoffersson      Sweden    €1K
# 18204           B. Worman     England    €1K
# 18205      D. Walker-Rice     England    €1K
# 18206           G. Nugent     England    €1K
#
# [18207 rows x 3 columns]

# %%
### puxar informações por linhas
dados.iloc[1] #traz informações da entrada numero [ n ]
dados.iloc[0:4] #traz informações da entrada numero até outro numero [ n : n]
dados.iloc[2,2] # puxar coluna n virgula linha n [ C , L ]
# Out:
# 'Neymar Jr'

# %%
## nova aula

import pandas as pd
dados = pd.read_csv("dataSet's/fifa.csv")

# %%
# função de localização .loc 
# primeiro coloca a base e a coluna depois o == ao que você quer
dados.loc[dados['Nationality'] == 'Brazil'] # Da para mudar para dados.loc[dados['Nationality'] == 'Spain']
dados.loc[dados['Age'] == 21]
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 155           155  231443      O. Dembélé   21
# 156           156  230666   Gabriel Jesus   21
# 228           228  230658          Arthur   21
# 234           234  224411  Gonçalo Guedes   21
# 236           236  222737          Malcom   21
# ...           ...     ...             ...  ...
# 18112       18112  239857       Chen Zhao   21
# 18116       18116  243709    K. Moesgaard   21
# 18138       18138  243097     Yin Congyao   21
# 18147       18147  225510       D. Mackay   21
# 18167       18167  243112          Wu Lei   21
#
#                                                 Photo Nationality  \
# 155    https://cdn.sofifa.org/players/4/19/231443.png      France
# 156    https://cdn.sofifa.org/players/4/19/230666.png      Brazil
# 228    https://cdn.sofifa.org/players/4/19/230658.png      Brazil
# 234    https://cdn.sofifa.org/players/4/19/224411.png    Portugal
# ...

# %%
# Valores curtos baseado no que está dentro dos ( ) 
dados.sort_values('Age') # posso adicionar o , ascending = false e isso vai inverter a lista do maior para o menor
dados.sort_values(['Name', 'Age']) # Filtra baseado nos 2, primeiro Nome, depois organiza pela Idade
dados.sort_values('Weight')
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 13338       13338  235600   B. Al Mutairi   28
# 17157       17157  242566    K. Yamaguchi   23
# 4390         4390  214919        D. Rojas   23
# 7126         7126  225150       A. Araujo   21
# 15585       15585  227726     I. Al Talhi   23
# ...           ...     ...             ...  ...
# 13279       13279  239679    P. Mazzocchi   22
# 13280       13280  244543       Y. Ammour   19
# 13281       13281  212800  Jwa Joon Hyeop   27
# 13282       13282  231232      O. Marrufo   25
# 13283       13283  232256     Han Pengfei   25
#
#                                                 Photo     Nationality  \
# 13338  https://cdn.sofifa.org/players/4/19/235600.png    Saudi Arabia
# 17157  https://cdn.sofifa.org/players/4/19/242566.png           Japan
# 4390   https://cdn.sofifa.org/players/4/19/214919.png           Chile
# 7126   https://cdn.sofifa.org/players/4/19/225150.png        Portugal
# ...

# %%
## Definindo quem é o melhor jogador baseado na aceleração, Agilidade e reação
dados['Total'] = dados['Acceleration'] + dados['Agility'] + dados['Reactions']
dados
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
dados = dados [['Name', 'Total']]
dados.sort_values('Total', ascending = False)
# Out:
#                  Name  Total
# 2           Neymar Jr  284.0
# 5           E. Hazard  279.0
# 0            L. Messi  277.0
# 26           M. Salah  276.0
# 50         D. Mertens  275.0
# ...               ...    ...
# 13279    P. Mazzocchi    NaN
# 13280       Y. Ammour    NaN
# 13281  Jwa Joon Hyeop    NaN
# 13282      O. Marrufo    NaN
# 13283     Han Pengfei    NaN
#
# [18207 rows x 2 columns]

# %%
## nova aula

import pandas as pd

dados = pd.read_csv("dataSet's/fifa.csv")
dados['Total'] = dados['Acceleration'] + dados['Agility'] + dados['Reactions']

dados = dados [['Name', 'Total']]
dados.sort_values('Total', ascending = False)

dados.head(5)
# Out:
#                 Name  Total
# 0           L. Messi  277.0
# 1  Cristiano Ronaldo  272.0
# 2          Neymar Jr  284.0
# 3             De Gea  207.0
# 4       K. De Bruyne  248.0

# %%
# para salvar um arquivo usar o to_nomedaextensão
# para excluir o index é , index = False
dados.to_csv('arquivosGerados/dados1.csv', index = False)

# %%
# para excluir o index é , index = False
# salvando para excel
dados.to_excel('arquivosGerados/dados2.xlsx', index = False)

# %%
# para excluir o index é , index = False
# salvando para txt
# utilizando o sep=' '
dados.to_csv('arquivosGerados/dados3.txt', index = False, sep='\t')
